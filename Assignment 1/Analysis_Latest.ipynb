# %% [markdown]
# # Data Analysis: Education, Literacy, and UN Speech Patterns in Africa
#
# ## Research Questions
#
# ### 1- Exploratory Research Question:
# Is there a correlation between the frequency of education-related words in African country speeches and literacy rates?
#
# ### 2- Predictive Research Question:
# Can we predict literacy rates using education expenditure and the frequency of education-related words in a multi-regression model? **Change**
#
# ## Hypotheses
#
# - There is a significant correlation between education word frequency and literacy rates.
# - CHANGE: **Not sure yet, we need to do some research before this!**
#
#
# ## Methodology Overview
#
# 1. Data Integration: Combine UN speech data, literacy rates, and education expenditure data for African countries
# 2. Text Processing: Extract and count education-related terms from UN speeches
# 3. Exploratory Analysis: Examine relationships between variables
# 4. Statistical Analysis: Investigate correlations and regression modeling

# %% [markdown]
# ## 1. Data Loading and Initial Setup

# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import scipy.stats as stats
import unicodedata
import re
from collections import Counter
import pandas as pd
# If needed, install the requirements
#!pip install -r requirements.txt

# %% [markdown]
# ### 1.1 Load UN Speeches Data

# %%
# Load UN Speeches from text files
sessions = np.arange(1, 80) # include all sessions
data = []

for session in sessions:
    directory = "./Data/TXT/Session "+str(str(session).zfill(2))+" - "+str(1945+session)
    for filename in os.listdir(directory):
        with open(os.path.join(directory, filename)) as f:
            if filename[0]==".": #ignore hidden files
                continue
            splt = filename.split("_")
            data.append([session, 1945+session, splt[0], f.read()])

# Create DataFrame and extract fundamental information about the data
df_speech = pd.DataFrame(data, columns=['Session', 'Year', 'ISO-alpha3 Code', 'Speech'])
print(f"Loaded {len(df_speech)} speeches from {df_speech['Year'].nunique()} years")
print(f"Year range: {df_speech['Year'].min()}-{df_speech['Year'].max()}")
print(f"Number of unique countries: {df_speech['ISO-alpha3 Code'].nunique()}")

# Check the dataframe
df_speech.tail(20)
#df_speech.head(20)
# Out:
# Loaded 10952 speeches from 79 years
# Year range: 1946-2024
# Number of unique countries: 200
#        Session  Year ISO-alpha3 Code  \
# 10932       79  2024             DEU
# 10933       79  2024             PSE
# 10934       79  2024             PER
# 10935       79  2024             LTU
# 10936       79  2024             SVN
# 10937       79  2024             SYC
# 10938       79  2024             KEN
# 10939       79  2024             KHM
# 10940       79  2024             MDV
# 10941       79  2024             ISR
# 10942       79  2024             KNA
# 10943       79  2024             VUT
# 10944       79  2024             CHE
# 10945       79  2024             CUB
# 10946       79  2024             ERI
# 10947       79  2024             CIV
# 10948       79  2024             HND
# 10949       79  2024             MKD
# 10950       79  2024             KOR
# 10951       79  2024             SGP
#
#                                                   Speech
# 10932  Excellencies, Ladies and Gentlemen, \n \nwe li...
# 10933  Mr. Philemon Yang, President of the United Nat...
# 10934  Mr President of the United Nations General Ass...
# 10935  Dear President of the General Assembly, \nExce...
# 10936  Mr President,  \n \nMr Secretary-General,  \n ...
# 10937  Mr President,  \nMr Secretary-General (if in t...
# 10938  President of the 79th Session of the UN Genera...
# 10939  Excellency Philémon Yang, President of the Gen...
# 10940  Mr President, \n \nMr Secretary General, \n \n...
# 10941  Mr. President, Ladies and gentlemen, I didn’t ...
# 10942    \nRemarks at 79th Session of United Na5ons G...
# 10943  **Mr President,**  \n**Excellencies, Heads of ...
# 10944  Mr President\nSecretary-General\nExcellencies\...
# 10945  **Mr President,**  \n**Mr Secretary-General,**...
# 10946  1\nYour Excellency Philemon Yang\nPresident of...
# 10947  Mr President of the 79th Session of the United...
# 10948  Madam President of this General Assembly,  \nM...
# 10949  Distinguished President of the United Nations ...
# 10950  Mr. President,\nMr. Secretary-General,\nDistin...
# 10951  Mdm President, Your Excellencies \n  \n  \n1 I...

# %% [markdown]
# ### 1.2 Load Country Codes and Regional Information

# %%
# Load country codes and regional information
codes_path = "./Data/UNSD_Methodology.csv"
df_codes = pd.read_csv(codes_path, sep=";")

# Extract fundamental information about the data
print(f"Country codes dataset shape: {df_codes.shape}")
print(f"Regions available: {df_codes['Region Name'].unique()}")

# Check the dataframe
df_codes.head(20)
#df_codes.tail(20)
# Out:
# Country codes dataset shape: (248, 15)
# Regions available: ['Africa' 'Americas' nan 'Asia' 'Europe' 'Oceania']
#     Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 0             1       World          2.0      Africa             15.0
# 1             1       World          2.0      Africa             15.0
# 2             1       World          2.0      Africa             15.0
# 3             1       World          2.0      Africa             15.0
# 4             1       World          2.0      Africa             15.0
# 5             1       World          2.0      Africa             15.0
# 6             1       World          2.0      Africa             15.0
# 7             1       World          2.0      Africa            202.0
# 8             1       World          2.0      Africa            202.0
# 9             1       World          2.0      Africa            202.0
# 10            1       World          2.0      Africa            202.0
# 11            1       World          2.0      Africa            202.0
# 12            1       World          2.0      Africa            202.0
# 13            1       World          2.0      Africa            202.0
# 14            1       World          2.0      Africa            202.0
# 15            1       World          2.0      Africa            202.0
# 16            1       World          2.0      Africa            202.0
# 17            1       World          2.0      Africa            202.0
# 18            1       World          2.0      Africa            202.0
# 19            1       World          2.0      Africa            202.0
#
#        Sub-region Name  Intermediate Region Code Intermediate Region Name  \
# 0      Northern Africa                       NaN                      NaN
# 1      Northern Africa                       NaN                      NaN
# 2      Northern Africa                       NaN                      NaN
# 3      Northern Africa                       NaN                      NaN
# 4      Northern Africa                       NaN                      NaN
# 5      Northern Africa                       NaN                      NaN
# 6      Northern Africa                       NaN                      NaN
# 7   Sub-Saharan Africa                      14.0           Eastern Africa
# 8   Sub-Saharan Africa                      14.0           Eastern Africa
# 9   Sub-Saharan Africa                      14.0           Eastern Africa
# 10  Sub-Saharan Africa                      14.0           Eastern Africa
# 11  Sub-Saharan Africa                      14.0           Eastern Africa
# 12  Sub-Saharan Africa                      14.0           Eastern Africa
# 13  Sub-Saharan Africa                      14.0           Eastern Africa
# 14  Sub-Saharan Africa                      14.0           Eastern Africa
# 15  Sub-Saharan Africa                      14.0           Eastern Africa
# 16  Sub-Saharan Africa                      14.0           Eastern Africa
# 17  Sub-Saharan Africa                      14.0           Eastern Africa
# 18  Sub-Saharan Africa                      14.0           Eastern Africa
# 19  Sub-Saharan Africa                      14.0           Eastern Africa
#
#                    Country or Area  M49 Code ISO-alpha2 Code ISO-alpha3 Code  \
# 0                          Algeria        12              DZ             DZA
# 1                            Egypt       818              EG             EGY
# 2                            Libya       434              LY             LBY
# 3                          Morocco       504              MA             MAR
# 4                            Sudan       729              SD             SDN
# 5                          Tunisia       788              TN             TUN
# 6                   Western Sahara       732              EH             ESH
# 7   British Indian Ocean Territory        86              IO             IOT
# 8                          Burundi       108              BI             BDI
# 9                          Comoros       174              KM             COM
# 10                        Djibouti       262              DJ             DJI
# 11                         Eritrea       232              ER             ERI
# 12                        Ethiopia       231              ET             ETH
# 13     French Southern Territories       260              TF             ATF
# 14                           Kenya       404              KE             KEN
# 15                      Madagascar       450              MG             MDG
# 16                          Malawi       454              MW             MWI
# 17                       Mauritius       480              MU             MUS
# 18                         Mayotte       175              YT             MYT
# 19                      Mozambique       508              MZ             MOZ
#
#    Least Developed Countries (LDC) Land Locked Developing Countries (LLDC)  \
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                                x                                     NaN
# 5                              NaN                                     NaN
# 6                              NaN                                     NaN
# 7                              NaN                                     NaN
# 8                                x                                       x
# 9                                x                                     NaN
# 10                               x                                     NaN
# 11                               x                                     NaN
# 12                               x                                       x
# 13                             NaN                                     NaN
# 14                             NaN                                     NaN
# 15                               x                                     NaN
# 16                               x                                       x
# 17                             NaN                                     NaN
# 18                             NaN                                     NaN
# 19                               x                                     NaN
#
#    Small Island Developing States (SIDS)
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                      x
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                     x
# 18                                   NaN
# 19                                   NaN

# %% [markdown]
# ### 1.2.1 Merging the UN Speeches with Region-Country Information

# %%
# Merge speeches with country information
df_un_merged = pd.merge(
    df_speech[["ISO-alpha3 Code", "Session", "Year", "Speech"]],
    df_codes[["Country or Area", "Region Name", "ISO-alpha3 Code"]],
    on="ISO-alpha3 Code",
    how="left"
)

# Print fundamental information about the merged dataframe
print(f"Merged dataset shape: {df_un_merged.shape}")

# Print the unique countries without the region name
print("All rows with missing Region Name:")
print(df_un_merged[df_un_merged["Region Name"].isna()])

print("Unique countries/entities with missing Region Name:")
print(df_un_merged[df_un_merged["Region Name"].isna()][["ISO-alpha3 Code", "Country or Area"]].drop_duplicates()) # None of them in Africa, so skip.

# Check the dataframe
df_un_merged.head(20) # or df_un_merged.tail(20)
# Out:
# Merged dataset shape: (10952, 6)
# All rows with missing Region Name:
#       ISO-alpha3 Code  Session  Year  \
# 14                CSK        1  1946
# 36                YUG        1  1946
# 52                YUG        2  1947
# 68                CSK        2  1947
# 84                CSK        3  1948
# ...               ...      ...   ...
# 10008              EU       75  2020
# 10306              EU       76  2021
# 10491              EU       77  2022
# 10619              EU       78  2023
# 10838              EU       79  2024
#
#                                                   Speech Country or Area  \
# 14     I am a little more moved than usual as I rise ...             NaN
# 36     In his report to the General Assembly, the Sec...             NaN
# 52     The United Nations, and particularly those amo...             NaN
# 68     May I congratulate my distinguished Mead and c...             NaN
# 84     Mr. CLEMENTIS stated that, in connexion with t...             NaN
# ...                                                  ...             ...
# 10008  Mister President, Mister Secretary-General, de...             NaN
# 10306  Nadia Murad was born in Iraq. Nadia Murad is Y...             NaN
# 10491  In Senegal last December, I met doctors and re...             NaN
# 10619  The Security Council Chamber is decorated with...             NaN
# 10838  Mr President of the General Assembly,  \nExcel...             NaN
#
#       Region Name
# 14            NaN
# 36            NaN
# 52            NaN
# 68            NaN
# 84            NaN
# ...           ...
# 10008         NaN
# 10306         NaN
# 10491         NaN
# 10619         NaN
# 10838         NaN
#
# [150 rows x 6 columns]
# Unique countries/entities with missing Region Name:
#      ISO-alpha3 Code Country or Area
# 14               CSK             NaN
# 36               YUG             NaN
# 1527             YMD             NaN
# 2058             DDR             NaN
# 8271              EU             NaN
#    ISO-alpha3 Code  Session  Year  \
# 0              LBR        1  1946
# 1              UKR        1  1946
# 2              IRN        1  1946
# 3              CAN        1  1946
# 4              HTI        1  1946
# 5              USA        1  1946
# 6              CUB        1  1946
# 7              COL        1  1946
# 8              CHL        1  1946
# 9              PER        1  1946
# 10             SAU        1  1946
# 11             LBN        1  1946
# 12             NLD        1  1946
# 13             AUS        1  1946
# 14             CSK        1  1946
# 15             EGY        1  1946
# 16             NZL        1  1946
# 17             MEX        1  1946
# 18             GBR        1  1946
# 19             CHN        1  1946
#
#                                                Speech  \
# 0   I give you the greetings of the Government and...
# 1   The day before yesterday the head of the deleg...
# 2   During the first part of the first session of ...
# 3   If  were not anxious, like all my colleagues, ...
# 4   A new world is being born from the fragments o...
# 5   At the outset of what I have to say to the Gen...
# 6   The Cuban delegation earnestly hopes that the ...
# 7   The Colombian delegation does not consider it ...
# 8   I shall occupy this rostrum for a few minutes ...
# 9   When I had the honour of addressing the Genera...
# 10  Saudi Arabia solemnly acclaims this meeting of...
# 11  The Lebanese delegation takes advantage of the...
# 12  We wish to limit our participation in this gen...
# 13  The General Assembly of the United Nations is ...
# 14  I am a little more moved than usual as I rise ...
# 15  It is for me a great pleasure to bring you tod...
# 16  I desire to take advantage of this opportunity...
# 17  Our presence in New York affords objective pro...
# 18  In his great pronouncement here the other day,...
# 19  My first words must be to express to the Gover...
#
#                                       Country or Area Region Name
# 0                                             Liberia      Africa
# 1                                             Ukraine      Europe
# 2                          Iran (Islamic Republic of)        Asia
# 3                                              Canada    Americas
# 4                                               Haiti    Americas
# 5                            United States of America    Americas
# 6                                                Cuba    Americas
# 7                                            Colombia    Americas
# 8                                               Chile    Americas
# 9                                                Peru    Americas
# 10                                       Saudi Arabia        Asia
# 11                                            Lebanon        Asia
# 12                       Netherlands (Kingdom of the)      Europe
# 13                                          Australia     Oceania
# 14                                                NaN         NaN
# 15                                              Egypt      Africa
# 16                                        New Zealand     Oceania
# 17                                             Mexico    Americas
# 18  United Kingdom of Great Britain and Northern I...      Europe
# 19                                              China        Asia

# %% [markdown]
# ### 1.3 Extract Countries within the Africa Region

# %%
# Filter for African countries
df_africa = df_un_merged[df_un_merged["Region Name"] == "Africa"].copy()

# Print fundamental information about the dataframe
print(f"African countries dataset shape: {df_africa.shape}")
print(f"\nNumber of African countries: {df_africa['Country or Area'].nunique()}")
print(f"\nYear range for African speeches: {df_africa['Year'].min()}-{df_africa['Year'].max()}")
print(f"\nAfrican countries in dataset:\n{df_africa['Country or Area'].unique()}")
print(f"\nMissing values per column:\n{df_africa.isna().sum()}")

# Search for non-ASCII characters
for col in ["Speech"]:
    non_ascii_rows = []
    for idx, val in df_africa[col].astype(str).items():
        for ch in val:
            if not ch.isascii():
                non_ascii_rows.append(idx)
                break
    print(f"\nColumn: {col}")
    print(f"Rows with non-ASCII characters: {len(non_ascii_rows)}")
    if non_ascii_rows:
        print(df_africa.loc[non_ascii_rows, [col, "Year"]].head(10))

# Check the dataframe
df_africa.head(20)
df_africa.tail(20)
# Out:
# African countries dataset shape: (3001, 6)
#
# Number of African countries: 54
#
# Year range for African speeches: 1946-2024
#
# African countries in dataset:
# ['Liberia' 'Egypt' 'South Africa' 'Ethiopia' 'Sudan' 'Morocco' 'Libya'
#  'Tunisia' 'Ghana' 'Guinea' 'Cameroon' 'Mali' 'Congo' 'Niger'
#  'Democratic Republic of the Congo' 'Central African Republic'
#  'Madagascar' 'Togo' 'Sierra Leone' 'Gabon' 'Somalia' 'Nigeria' 'Senegal'
#  'Burkina Faso' 'Algeria' 'Mauritania' 'Benin' 'Uganda' 'Chad'
#  'United Republic of Tanzania' 'Burundi' 'Rwanda' 'Malawi' 'Kenya'
#  'Zambia' 'Côte d’Ivoire' 'Lesotho' 'Gambia' 'Botswana' 'Mauritius'
#  'Equatorial Guinea' 'Eswatini' 'Mozambique' 'Sao Tome and Principe'
#  'Cabo Verde' 'Guinea-Bissau' 'Comoros' 'Seychelles' 'Angola' 'Djibouti'
#  'Zimbabwe' 'Namibia' 'Eritrea' 'South Sudan']
#
# Missing values per column:
# ISO-alpha3 Code    0
# Session            0
# Year               0
# Speech             0
# Country or Area    0
# Region Name        0
# dtype: int64
#
# Column: Speech
# Rows with non-ASCII characters: 2663
#                                                 Speech  Year
# 0    I give you the greetings of the Government and...  1946
# 15   It is for me a great pleasure to bring you tod...  1946
# 59   During the recent war, many of the nations rep...  1947
# 67   In the name of my delegation, permit me to ass...  1947
# 91   Mr. COOPER stated that all the nations of the ...  1948
# 92   Mr. Louw expressed his thanks to France on beh...  1948
# 118  Mr. JOOSTE stated that it was the wish of his ...  1949
# 127  RAHIM Bey said that the political atmosphere i...  1949
# 146  Mr. AKLILOU wished to comment briefly on the a...  1949
# 158  A year ago, when the fourth session of the Gen...  1950
#       ISO-alpha3 Code  Session  Year  \
# 10885             GAB       79  2024
# 10886             MWI       79  2024
# 10887             BEN       79  2024
# 10891             STP       79  2024
# 10894             CMR       79  2024
# 10895             LBR       79  2024
# 10898             UGA       79  2024
# 10899             CPV       79  2024
# 10901             EGY       79  2024
# 10902             SLE       79  2024
# 10907             TGO       79  2024
# 10908             LSO       79  2024
# 10911             TCD       79  2024
# 10915             AGO       79  2024
# 10920             TZA       79  2024
# 10925             GMB       79  2024
# 10937             SYC       79  2024
# 10938             KEN       79  2024
# 10946             ERI       79  2024
# 10947             CIV       79  2024
#
#                                                   Speech  \
# 10885  Mr President of the General Assembly,  \nLadie...
# 10886  •   Your Excellency Philémon Yang President of...
# 10887  Mr President of the General Assembly,  \nExcel...
# 10891  Mr. Philemon Yang, President of the General As...
# 10894  **MR PRESIDENT,**  \n\nI am honoured to delive...
# 10895  \nH.E. Philemon Yangon, President of the 79th ...
# 10898  The President of the General Assembly, \nExcel...
# 10899  Excellencies Heads of State, Mr. President of ...
# 10901  \n**Mr. President,**  \n**Ladies and Gentlemen...
# 10902   MR. PRESIDENT, \n1.\tI congratulate Your Exce...
# 10907  Mr President,  \nExcellencies, Heads of State ...
# 10908  YOUR EXCELLENCY AMBASSADOR PHILEMON YANG, PRES...
# 10911  Mr President of the General Assembly,  \nExcel...
# 10915  -Your Excellency Philémon Yang  \nPresident of...
# 10920  • Your Excellency, Philemon Yang, President of...
# 10925  President of the 79th Session of the UN Genera...
# 10937  Mr President,  \nMr Secretary-General (if in t...
# 10938  President of the 79th Session of the UN Genera...
# 10946  1\nYour Excellency Philemon Yang\nPresident of...
# 10947  Mr President of the 79th Session of the United...
#
#                    Country or Area Region Name
# 10885                        Gabon      Africa
# 10886                       Malawi      Africa
# 10887                        Benin      Africa
# 10891        Sao Tome and Principe      Africa
# 10894                     Cameroon      Africa
# 10895                      Liberia      Africa
# 10898                       Uganda      Africa
# 10899                   Cabo Verde      Africa
# 10901                        Egypt      Africa
# 10902                 Sierra Leone      Africa
# 10907                         Togo      Africa
# 10908                      Lesotho      Africa
# 10911                         Chad      Africa
# 10915                       Angola      Africa
# 10920  United Republic of Tanzania      Africa
# 10925                       Gambia      Africa
# 10937                   Seychelles      Africa
# 10938                        Kenya      Africa
# 10946                      Eritrea      Africa
# 10947                Côte d’Ivoire      Africa

# %% [markdown]
# ### 1.3.1 Clean & Preprocess the Africa Dataset

# %%
# Define a pre-process function to normalize all text to lowercase, whitespace between, no special characters etc.
def preprocess_text(s: str) -> str:
    if pd.isna(s):
        return s
    # normalize unicode accents → ascii
    s = unicodedata.normalize("NFKD", s).encode("ascii", "ignore").decode("utf-8")

    # lowercase
    s = s.lower()

    # remove markdown bold/italics markers (i.e., ** and *)
    s = re.sub(r"\*+", "", s)

    # replace newlines/tabs with space
    s = re.sub(r"[\n\t\r]+", " ", s)

    # collapse multiple spaces into one
    s = re.sub(r"\s+", " ", s)

    # strip leading/trailing spaces
    return s.strip()

# Apply to Speech
df_africa["Speech"] = df_africa["Speech"].apply(preprocess_text)

# Check the dataframe
df_africa.head(20) # or df_africa.tail(20)
# Out:
#     ISO-alpha3 Code  Session  Year  \
# 0               LBR        1  1946
# 15              EGY        1  1946
# 59              ZAF        2  1947
# 65              LBR        2  1947
# 67              EGY        2  1947
# 83              EGY        3  1948
# 91              LBR        3  1948
# 92              ZAF        3  1948
# 118             ZAF        4  1949
# 122             LBR        4  1949
# 127             EGY        4  1949
# 146             ETH        4  1949
# 158             ETH        5  1950
# 183             EGY        5  1950
# 189             LBR        5  1950
# 193             ZAF        5  1950
# 202             EGY        6  1951
# 212             ZAF        6  1951
# 219             LBR        6  1951
# 226             ETH        6  1951
#
#                                                 Speech Country or Area  \
# 0    i give you the greetings of the government and...         Liberia
# 15   it is for me a great pleasure to bring you tod...           Egypt
# 59   during the recent war, many of the nations rep...    South Africa
# 65   the liberian delegation wishes to associate it...         Liberia
# 67   in the name of my delegation, permit me to ass...           Egypt
# 83   khashaba pasha stated that on the occasion of ...           Egypt
# 91   mr. cooper stated that all the nations of the ...         Liberia
# 92   mr. louw expressed his thanks to france on beh...    South Africa
# 118  mr. jooste stated that it was the wish of his ...    South Africa
# 122  mr. king, after congratulating the president u...         Liberia
# 127  rahim bey said that the political atmosphere i...           Egypt
# 146  mr. aklilou wished to comment briefly on the a...        Ethiopia
# 158  a year ago, when the fourth session of the gen...        Ethiopia
# 183  the general assembly holds its present meeting...           Egypt
# 189  in view of the very lengthy agenda that has be...         Liberia
# 193  i should like to express from this rostrum the...    South Africa
# 202  in this general debate, each of us, in his tur...           Egypt
# 212  may i at the outset add the thanks of the sout...    South Africa
# 219  one might wonder why such a small country as l...         Liberia
# 226  my delegation, before addressing this august a...        Ethiopia
#
#     Region Name
# 0        Africa
# 15       Africa
# 59       Africa
# 65       Africa
# 67       Africa
# 83       Africa
# 91       Africa
# 92       Africa
# 118      Africa
# 122      Africa
# 127      Africa
# 146      Africa
# 158      Africa
# 183      Africa
# 189      Africa
# 193      Africa
# 202      Africa
# 212      Africa
# 219      Africa
# 226      Africa

# %% [markdown]
# ### 1.4  Load Literacy Rates Data

# %%
# Load literacy rates dataset
df_literacy = pd.read_csv("Data/WB_GS_SE_ADT.csv")

# Print fundamental information about the data
print(f"Literacy dataset shape: {df_literacy.shape}")
print(f"Year range: {df_literacy['TIME_PERIOD'].min()}-{df_literacy['TIME_PERIOD'].max()}")
print(f"Missing values: {df_literacy['OBS_VALUE'].isna().mean()*100:.1f}%")
print(f"Number of countries/regions: {df_literacy['REF_AREA_LABEL'].nunique()}\n")
print(df_literacy.info())     # column names + types
print("\nCountries/Regions:", df_literacy["REF_AREA_LABEL"].nunique())
print(df_literacy["REF_AREA_LABEL"].unique()[:10])   # first 10 countries

print("\nSex categories:", df_literacy["SEX_LABEL"].unique())
print("\nAge groups:", df_literacy["AGE_LABEL"].unique())
print("\nUrbanisation categories:", df_literacy["URBANISATION_LABEL"].unique())
print("\nIndicators:", df_literacy["INDICATOR_LABEL"].unique())

# Check the dataframe
df_literacy.head(20)
# Out:
# Literacy dataset shape: (101760, 35)
# Year range: 1960-2023
# Missing values: 83.3%
# Number of countries/regions: 265
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101760 entries, 0 to 101759
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   STRUCTURE               101760 non-null  object
#  1   STRUCTURE_ID            101760 non-null  object
#  2   ACTION                  101760 non-null  object
#  3   FREQ                    101760 non-null  object
#  4   FREQ_LABEL              101760 non-null  object
#  5   REF_AREA                101760 non-null  object
#  6   REF_AREA_LABEL          101760 non-null  object
#  7   INDICATOR               101760 non-null  object
#  8   INDICATOR_LABEL         101760 non-null  object
#  9   SEX                     101760 non-null  object
#  10  SEX_LABEL               101760 non-null  object
#  11  AGE                     101760 non-null  object
#  12  AGE_LABEL               101760 non-null  object
#  13  URBANISATION            101760 non-null  object
#  14  URBANISATION_LABEL      101760 non-null  object
#  15  UNIT_MEASURE            101760 non-null  object
#  16  UNIT_MEASURE_LABEL      101760 non-null  object
#  17  COMP_BREAKDOWN_1        101760 non-null  object
#  18  COMP_BREAKDOWN_1_LABEL  101760 non-null  object
#  19  COMP_BREAKDOWN_2        101760 non-null  object
#  20  COMP_BREAKDOWN_2_LABEL  101760 non-null  object
#  21  COMP_BREAKDOWN_3        101760 non-null  object
#  22  COMP_BREAKDOWN_3_LABEL  101760 non-null  object
#  23  TIME_PERIOD             101760 non-null  int64
#  24  OBS_VALUE               16961 non-null   float64
#  25  DATABASE_ID             101760 non-null  object
#  26  DATABASE_ID_LABEL       101760 non-null  object
#  27  UNIT_MULT               101760 non-null  int64
#  28  UNIT_MULT_LABEL         101760 non-null  object
#  29  UNIT_TYPE               101760 non-null  object
#  30  UNIT_TYPE_LABEL         101760 non-null  object
#  31  OBS_STATUS              101760 non-null  object
#  32  OBS_STATUS_LABEL        101760 non-null  object
#  33  OBS_CONF                101760 non-null  object
#  34  OBS_CONF_LABEL          101760 non-null  object
# dtypes: float64(1), int64(2), object(32)
# memory usage: 27.2+ MB
# None
#
# Countries/Regions: 265
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina']
#
# Sex categories: ['Female' 'Male' 'Total']
#
# Age groups: ['15 to 24 years old' '15 years old and over']
#
# Urbanisation categories: ['Total']
#
# Indicators: ['Literacy rate (%)']
#         STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      ABW
# 1   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      AFE
# 2   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      AFG
# 3   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      AFW
# 4   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      AGO
# 5   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      ALB
# 6   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      AND
# 7   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      ARB
# 8   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      ARE
# 9   datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      ARG
# 10  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      ARM
# 11  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      ASM
# 12  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      ATG
# 13  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      AUS
# 14  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      AUT
# 15  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      AZE
# 16  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      BDI
# 17  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      BEL
# 18  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      BEN
# 19  datastructure  WB.DATA360:DS_DATA360(1.1)      I    A     Annual      BFA
#
#                  REF_AREA_LABEL     INDICATOR    INDICATOR_LABEL SEX  ...  \
# 0                         Aruba  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 1   Africa Eastern and Southern  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 2                   Afghanistan  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 3    Africa Western and Central  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 4                        Angola  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 5                       Albania  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 6                       Andorra  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 7                    Arab World  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 8          United Arab Emirates  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 9                     Argentina  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 10                      Armenia  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 11               American Samoa  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 12          Antigua and Barbuda  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 13                    Australia  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 14                      Austria  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 15                   Azerbaijan  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 16                      Burundi  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 17                      Belgium  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 18                        Benin  WB_GS_SE_ADT  Literacy rate (%)   F  ...
# 19                 Burkina Faso  WB_GS_SE_ADT  Literacy rate (%)   F  ...
#
#    DATABASE_ID  DATABASE_ID_LABEL UNIT_MULT UNIT_MULT_LABEL UNIT_TYPE  \
# 0        WB_GS  Gender Statistics         0           Units     RATIO
# 1        WB_GS  Gender Statistics         0           Units     RATIO
# 2        WB_GS  Gender Statistics         0           Units     RATIO
# 3        WB_GS  Gender Statistics         0           Units     RATIO
# 4        WB_GS  Gender Statistics         0           Units     RATIO
# 5        WB_GS  Gender Statistics         0           Units     RATIO
# 6        WB_GS  Gender Statistics         0           Units     RATIO
# 7        WB_GS  Gender Statistics         0           Units     RATIO
# 8        WB_GS  Gender Statistics         0           Units     RATIO
# 9        WB_GS  Gender Statistics         0           Units     RATIO
# 10       WB_GS  Gender Statistics         0           Units     RATIO
# 11       WB_GS  Gender Statistics         0           Units     RATIO
# 12       WB_GS  Gender Statistics         0           Units     RATIO
# 13       WB_GS  Gender Statistics         0           Units     RATIO
# 14       WB_GS  Gender Statistics         0           Units     RATIO
# 15       WB_GS  Gender Statistics         0           Units     RATIO
# 16       WB_GS  Gender Statistics         0           Units     RATIO
# 17       WB_GS  Gender Statistics         0           Units     RATIO
# 18       WB_GS  Gender Statistics         0           Units     RATIO
# 19       WB_GS  Gender Statistics         0           Units     RATIO
#
#    UNIT_TYPE_LABEL OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0            Ratio          O    Missing value       PU         Public
# 1            Ratio          O    Missing value       PU         Public
# 2            Ratio          O    Missing value       PU         Public
# 3            Ratio          O    Missing value       PU         Public
# 4            Ratio          O    Missing value       PU         Public
# 5            Ratio          O    Missing value       PU         Public
# 6            Ratio          O    Missing value       PU         Public
# 7            Ratio          O    Missing value       PU         Public
# 8            Ratio          O    Missing value       PU         Public
# 9            Ratio          O    Missing value       PU         Public
# 10           Ratio          O    Missing value       PU         Public
# 11           Ratio          O    Missing value       PU         Public
# 12           Ratio          O    Missing value       PU         Public
# 13           Ratio          O    Missing value       PU         Public
# 14           Ratio          O    Missing value       PU         Public
# 15           Ratio          O    Missing value       PU         Public
# 16           Ratio          O    Missing value       PU         Public
# 17           Ratio          O    Missing value       PU         Public
# 18           Ratio          O    Missing value       PU         Public
# 19           Ratio          O    Missing value       PU         Public
#
# [20 rows x 35 columns]

# %% [markdown]
# ### 1.4.1 Clean & Preprocess Literacy Rate Data

# %%
#TODO: preprocess this dataset as well. Check out missing, non-ascii, etc. IF needed.

# %% [markdown]
# ### 1.4.2 Merge Literacy Rates with Africa Dataset

# %%
# First, let's prepare the literacy data similar to what's done in cell 32
# Filter literacy data for Total population, 15+ age group, and non-null values
df_literacy_for_merge = df_literacy[
    (df_literacy['SEX_LABEL'] == 'Total') & 
    (df_literacy['AGE_LABEL'] == '15 years old and over') &
    (df_literacy['OBS_VALUE'].notna())
].copy()

# Rename columns for easier merging
df_literacy_for_merge = df_literacy_for_merge.rename(columns={
    'REF_AREA_LABEL': 'Country or Area',
    'TIME_PERIOD': 'Year', 
    'OBS_VALUE': 'Literacy_Rate'
})

# Check country name matching between datasets
africa_countries = set(df_africa['Country or Area'].unique())
literacy_countries = set(df_literacy_for_merge['Country or Area'].unique())

print("Countries in Africa dataset:", len(africa_countries))
print("Countries in literacy dataset:", len(literacy_countries))
print("Common countries:", len(africa_countries & literacy_countries))
print("\nCountries with literacy data available for Africa:")
print(sorted(africa_countries & literacy_countries))

# Merge literacy rates with Africa dataset
# Use left join to keep all Africa data, adding literacy rate where available
df_africa_with_literacy = pd.merge(
    df_africa,
    df_literacy_for_merge[['Country or Area', 'Year', 'Literacy_Rate']],
    on=['Country or Area', 'Year'],
    how='left'
)

# Print the resulting information
print(f"\nOriginal Africa dataset shape: {df_africa.shape}")
print(f"After adding literacy rates: {df_africa_with_literacy.shape}")
print(f"Rows with literacy data: {df_africa_with_literacy['Literacy_Rate'].notna().sum()}")
print(f"Coverage: {df_africa_with_literacy['Literacy_Rate'].notna().mean()*100:.1f}%")

# Update the main Africa dataframe
df_africa = df_africa_with_literacy

# Show sample of merged data
df_africa[df_africa['Literacy_Rate'].notna()]
# Out:
# Countries in Africa dataset: 54
# Countries in literacy dataset: 209
# Common countries: 47
#
# Countries with literacy data available for Africa:
# ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe']
#
# Original Africa dataset shape: (3001, 6)
# After adding literacy rates: (3001, 7)
# Rows with literacy data: 244
# Coverage: 8.1%
#      ISO-alpha3 Code  Session  Year  \
# 426              SOM       27  1972
# 551              CAF       30  1975
# 554              BFA       30  1975
# 575              CMR       31  1976
# 590              SWZ       31  1976
# ...              ...      ...   ...
# 2882             ZWE       77  2022
# 2885             BFA       77  2022
# 2886             GNB       77  2022
# 2892             MDG       77  2022
# 2894             TUN       77  2022
#
#                                                  Speech  \
# 426   mr. president, my foreign secretary had hoped ...
# 551   243. in the name of mr. jean-bedel bokassa, pr...
# 554   once again i should like to reaffirm in a few ...
# 575   our session opened a few days ago under the pr...
# 590   mr. president, i wish to express my sincere co...
# ...                                                 ...
# 2882  it is my singular honour to deliver this state...
# 2885  i would like to begin by expressing my warmest...
# 2886  i would like to warmly congratulate mr. csaba ...
# 2892  at the outset, allow me to address mr. korosi,...
# 2894  at the outset, i wish to congratulate mr. csab...
#
#                Country or Area Region Name  Literacy_Rate
# 426                    Somalia      Africa       5.404650
# 551   Central African Republic      Africa      18.236170
# 554               Burkina Faso      Africa       8.830230
# 575                   Cameroon      Africa      41.216209
# 590                   Eswatini      Africa      55.325039
# ...                        ...         ...            ...
# 2882                  Zimbabwe      Africa      89.849998
# 2885              Burkina Faso      Africa      34.490002
# 2886             Guinea-Bissau      Africa      53.900002
# 2892                Madagascar      Africa      77.480003
# 2894                   Tunisia      Africa      83.559998
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 1.5 Load Education Expenditure Data

# %%
# Load education expenditure dataset (Government expenditure on education as % of GDP)
df_edu_exp = pd.read_csv("Data/UIS_EDSTATS_XGDP_FSGOV.csv")

# Print fundamental information about the data
print(f"Education expenditure dataset shape: {df_edu_exp.shape}")
print(f"Year range: {df_edu_exp['TIME_PERIOD'].min()}-{df_edu_exp['TIME_PERIOD'].max()}")
print(f"Missing values: {df_edu_exp['OBS_VALUE'].isna().mean()*100:.1f}%")
print(f"Number of countries: {df_edu_exp['REF_AREA_LABEL'].nunique()}")
print(f"\nExpenditure statistics:")
print(df_edu_exp['OBS_VALUE'].describe())

# Check the dataframe
df_edu_exp.head()
# Out:
# Education expenditure dataset shape: (5334, 45)
# Year range: 1970-2024
# Missing values: 0.0%
# Number of countries: 206
#
# Expenditure statistics:
# count    5334.000000
# mean        4.352125
# std         2.146107
# min         0.000000
# 25%         3.047476
# 50%         4.192725
# 75%         5.376110
# max        66.900307
# Name: OBS_VALUE, dtype: float64
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ABW
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ABW
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ABW
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ABW
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ABW
#
#   REF_AREA_LABEL               INDICATOR  \
# 0          Aruba  UIS_EDSTATS_XGDP_FSGOV
# 1          Aruba  UIS_EDSTATS_XGDP_FSGOV
# 2          Aruba  UIS_EDSTATS_XGDP_FSGOV
# 3          Aruba  UIS_EDSTATS_XGDP_FSGOV
# 4          Aruba  UIS_EDSTATS_XGDP_FSGOV
#
#                                      INDICATOR_LABEL SEX  ...  \
# 0  Government expenditure on education as a perce...  _T  ...
# 1  Government expenditure on education as a perce...  _T  ...
# 2  Government expenditure on education as a perce...  _T  ...
# 3  Government expenditure on education as a perce...  _T  ...
# 4  Government expenditure on education as a perce...  _T  ...
#
#       DATA_SOURCE_LABEL UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT  \
# 0  Education Statistics     RATIO           Ratio         602
# 1  Education Statistics     RATIO           Ratio         602
# 2  Education Statistics     RATIO           Ratio         602
# 3  Education Statistics     RATIO           Ratio         602
# 4  Education Statistics     RATIO           Ratio         602
#
#   TIME_FORMAT_LABEL COMMENT_OBS OBS_STATUS OBS_STATUS_LABEL OBS_CONF  \
# 0              CCYY         NaN          A     Normal value       PU
# 1              CCYY         NaN          A     Normal value       PU
# 2              CCYY         NaN          A     Normal value       PU
# 3              CCYY         NaN          A     Normal value       PU
# 4              CCYY         NaN          A     Normal value       PU
#
#   OBS_CONF_LABEL
# 0         Public
# 1         Public
# 2         Public
# 3         Public
# 4         Public
#
# [5 rows x 45 columns]

# %% [markdown]
# ### 1.5.1. Preprocess & Clean Education Expenditure Data

# %%
#TODO: preprocess this dataset as well. Check out missing, non-ascii, etc.

# %% [markdown]
# ### 1.5.2. Merge Education Expenditure Data with African Dataset

# %%
# Merge Education Expenditure Data with Africa Dataset

# Prepare education expenditure data
df_edu_exp_for_merge = df_edu_exp[df_edu_exp['OBS_VALUE'].notna()].copy()

# Rename columns for easier merging
df_edu_exp_for_merge = df_edu_exp_for_merge.rename(columns={
    'REF_AREA_LABEL': 'Country or Area',
    'TIME_PERIOD': 'Year',
    'OBS_VALUE': 'Education_Expenditure_GDP_Pct'
})

# Check which African countries have education expenditure data
african_countries_in_speeches = set(df_africa['Country or Area'].unique())
african_countries_in_expenditure = set(df_edu_exp_for_merge['Country or Area'].unique())

print("Countries in Africa speeches dataset:", len(african_countries_in_speeches))
print("Countries in expenditure dataset:", len(african_countries_in_expenditure))

# Find common countries
common_countries = african_countries_in_speeches & african_countries_in_expenditure
print(f"Common countries between Africa and expenditure datasets: {len(common_countries)}")
print("Common countries:", common_countries)

# Merge education expenditure with Africa dataset
# Use left join to keep all Africa data, adding expenditure where available
df_africa_with_expenditure = pd.merge(
    df_africa,
    df_edu_exp_for_merge[['Country or Area', 'Year', 'Education_Expenditure_GDP_Pct']],
    on=['Country or Area', 'Year'],
    how='left'
)

# Update the main Africa dataframe
df_africa = df_africa_with_expenditure
# Out:
# Countries in Africa speeches dataset: 54
# Countries in expenditure dataset: 206
# Common countries between Africa and expenditure datasets: 48
# Common countries: {'Mali', 'South Africa', 'Mozambique', 'Madagascar', 'Mauritania', 'Morocco', 'South Sudan', 'Comoros', 'Eswatini', 'Somalia', 'Sudan', 'Ethiopia', 'Niger', 'Rwanda', 'Malawi', 'Libya', 'Benin', 'Uganda', 'Kenya', 'Central African Republic', 'Tunisia', 'Chad', 'Guinea-Bissau', 'Liberia', 'Zimbabwe', 'Algeria', 'Gabon', 'Sierra Leone', 'Lesotho', 'Burkina Faso', 'Nigeria', 'Burundi', 'Mauritius', 'Djibouti', 'Angola', 'Cabo Verde', 'Guinea', 'Botswana', 'Sao Tome and Principe', 'Equatorial Guinea', 'Senegal', 'Seychelles', 'Eritrea', 'Cameroon', 'Namibia', 'Togo', 'Zambia', 'Ghana'}

# %%
# Print the resulting information
print(f"\nOriginal Africa dataset shape: {df_africa.shape}")
print(f"After adding education expenditure: {df_africa_with_expenditure.shape}")
print(f"Rows with expenditure data: {df_africa_with_expenditure['Education_Expenditure_GDP_Pct'].notna().sum()}")
print(f"Expenditure coverage: {df_africa_with_expenditure['Education_Expenditure_GDP_Pct'].notna().mean()*100:.1f}%")
# Out:
# Original Africa dataset shape: (3001, 8)
# After adding education expenditure: (3001, 8)
# Rows with expenditure data: 1085
# Expenditure coverage: 36.2%

# %%
print("\nEducation expenditure statistics for African countries:")
print(df_africa['Education_Expenditure_GDP_Pct'].describe())

# Show sample of merged data with expenditure
sample_with_expenditure = df_africa[df_africa['Education_Expenditure_GDP_Pct'].notna()].head(10)
print(f"\nSample of African countries with education expenditure data:")
print(sample_with_expenditure[['Country or Area', 'Year', 'Education_Expenditure_GDP_Pct', 'Literacy_Rate']].to_string())

# Show rows where both Literacy_Rate and Education_Expenditure_GDP_Pct are not NA
both_notna = df_africa[
    df_africa['Literacy_Rate'].notna() & df_africa['Education_Expenditure_GDP_Pct'].notna()
]
# Show the rows that have both Literacy Rate and Education Expenditure_GDP
print(f"\nRows where both Literacy Rate and Education Expenditure are available: {both_notna.shape[0]}")
both_notna[['Country or Area', 'Year', 'Literacy_Rate', 'Education_Expenditure_GDP_Pct']].head(10)
# Out:
# Education expenditure statistics for African countries:
# count    1085.000000
# mean        4.193607
# std         2.454733
# min         0.127174
# 25%         2.572222
# 50%         3.736495
# 75%         5.438300
# max        44.333981
# Name: Education_Expenditure_GDP_Pct, dtype: float64
#
# Sample of African countries with education expenditure data:
#     Country or Area  Year  Education_Expenditure_GDP_Pct  Literacy_Rate
# 370          Zambia  1970                        4.38781            NaN
# 380            Togo  1970                        1.49681            NaN
# 389        Cameroon  1971                        3.07987            NaN
# 395          Uganda  1971                        3.16105            NaN
# 399           Kenya  1971                        3.92982            NaN
# 408          Zambia  1971                        6.09535            NaN
# 410        Ethiopia  1971                        1.19767            NaN
# 412           Niger  1971                        1.05227            NaN
# 413       Mauritius  1971                        3.11274            NaN
# 415           Ghana  1971                        4.22444            NaN
#
# Rows where both Literacy Rate and Education Expenditure are available: 164
#      Country or Area  Year  Literacy_Rate  Education_Expenditure_GDP_Pct
# 426          Somalia  1972       5.404650                        1.10284
# 590         Eswatini  1976      55.325039                        3.71435
# 683           Rwanda  1978      38.243431                        2.23247
# 738          Burundi  1979      22.508551                        2.80336
# 870          Morocco  1982      30.257799                        6.12268
# 969          Tunisia  1984      48.190701                        5.51745
# 1066          Malawi  1987      48.536652                        2.42225
# 1234       Mauritius  1990      79.868660                        3.12822
# 1237         Burundi  1990      37.384720                        3.35933
# 1310        Zimbabwe  1992      83.512581                       22.32221

# %% [markdown]
# ## 2. Education-Related Terms Extraction
#
# We extract education-related terms from the UNESCO thesaurus to identify relevant vocabulary in UN speeches.

# %%
# Load education-related terms from UNESCO thesaurus
with open("./Data/sh85040989.json", "r", encoding="utf-8") as f:
    education_glossary_data = json.load(f)

# Collect all the @value entries from the JSON, as education-related words are encoded within.
education_related_terms = []
for entry in education_glossary_data:
    for key, values in entry.items():
        if isinstance(values, list):
            for value in values:
                if isinstance(value, dict) and "@value" in value:
                    education_related_terms.append(value["@value"])

# Create DataFrame
df_education_terms = pd.DataFrame(education_related_terms, columns=["Education-related Key Word"])
print(f"Initial education terms extracted: {len(df_education_terms)}")
df_education_terms.head(20)
# Out:
# Initial education terms extracted: 942
#                       Education-related Key Word
# 0                     Human resource development
# 1                          Pictures in education
# 2                          Pictures in education
# 3   150  $aEducation$xAustralian states$xFinance
# 4          Education--Australian states--Finance
# 5          Education--Australian states--Finance
# 6                            Inclusive education
# 7                            Inclusive education
# 8           150  $aEducation$xEconometric models
# 9                  Education--Econometric models
# 10                 Education--Econometric models
# 11             150  $aEducation$xReference books
# 12                    Education--Reference books
# 13                    Education--Reference books
# 14                               Home and school
# 15                               Home and school
# 16                        Compensatory education
# 17                        Compensatory education
# 18                       Libraries and education
# 19                       Libraries and education

# %% [markdown]
# ### 2.1 Clean & Preprocess Education Terms Dataset

# %%
# Clean and preprocess education terms
df_education_terms_clean = df_education_terms.drop_duplicates()
print(f"After removing duplicates: {len(df_education_terms_clean)}")

# Remove entries that start with digits (library classification codes)
df_education_terms_clean = df_education_terms_clean[
    ~df_education_terms_clean["Education-related Key Word"].str[0].str.isdigit()
]
print(f"After removing entries starting with digits: {len(df_education_terms_clean)}")

# Replace double dashes with spaces
df_education_terms_clean["Education-related Key Word"] = df_education_terms_clean[
    "Education-related Key Word"].str.replace("--", " ")

# Normalize whitespaces and convert to lowercase
df_education_terms_clean["Education-related Key Word"] = df_education_terms_clean[
    "Education-related Key Word"].str.replace(r"\s+", " ", regex=True).str.strip().str.lower()

# Ensure ASCII-only characters
df_education_terms_clean["Education-related Key Word"] = df_education_terms_clean[
    "Education-related Key Word"].str.encode('ascii', 'ignore').str.decode('ascii')

print(f"Final cleaned education terms: {len(df_education_terms_clean)}")
print("\nSample cleaned terms:")
print(df_education_terms_clean.head(15))

#TODO: using the nltk library, check out the distribution of the education-related terms.
# Out:
# After removing duplicates: 516
# After removing entries starting with digits: 387
# Final cleaned education terms: 387
#
# Sample cleaned terms:
#                   Education-related Key Word
# 0                 human resource development
# 1                      pictures in education
# 4        education australian states finance
# 6                        inclusive education
# 9               education econometric models
# 12                 education reference books
# 14                           home and school
# 16                    compensatory education
# 18                   libraries and education
# 20                           youth education
# 22  education study and teaching (preschool)
# 25          education periodicals publishing
# 28                        education taxation
# 31   education us states aims and objectives
# 33                       technical education

# %% [markdown]
# ## 3. Education-Related Word Frequency Calculation
#
# ### 3.1 Methodology for Frequency Calculation
#
# This section will calculate the frequency of education-related words in African country speeches. The methodology involves:
#
# 1. Text Preprocessing:
#    - Tokenize each speech into individual words
#    - Convert to lowercase for case-insensitive matching
#    - Remove punctuation and special characters
#    - Remove stop words (common words like "the", "and", "of")
#
# 2. Term Matching:
#    - For each speech, count occurrences of each education-related term from our cleaned vocabulary
#    - Handle both exact matches and partial matches (e.g., "education" should match "educational")
#    - Consider word boundaries to avoid false matches
#
# 3. Frequency Metrics:
#    - Absolute Count: Total number of education-related words per speech
#    - Relative Frequency: Education words as percentage of total words in speech
#    - Normalized Score: Account for speech length variations
#    - Term Diversity: Number of unique education terms used
#
# 4. Aggregation Strategies:
#    - Country-Year Level: Sum frequencies for each country per year
#    - Country Level: Average frequencies across all years for each country
#    - Temporal Analysis: Track frequency changes over time
#
# ### 3.2 Implementation
#
# Expected Output: A new column in `df_africa` containing education word frequencies for each speech, which will enable correlation analysis with literacy rates.

# %%
# Download required NLTK libraries
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/bugrasipahioglu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/bugrasipahioglu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/bugrasipahioglu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/bugrasipahioglu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/bugrasipahioglu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Count education-related words in all speeches (of African countries)
def count_education_mentions(text: str):
    if pd.isna(text) or text.strip() == "":
        return {"n_tokens": 0, "edu_single_count": 0, "edu_phrase_count": 0,
                "edu_total": 0, "edu_per_1k": 0.0}
    
    # Use cleaned text directly, convert to lowercase for matching
    text_lower = text.lower()
    
    # Tokenize for counting total tokens
    toks = text_lower.split()
    n = len(toks)
    if n == 0:
        return {"n_tokens": 0, "edu_single_count": 0, "edu_phrase_count": 0,
                "edu_total": 0, "edu_per_1k": 0.0}

    # Get education terms from cleaned dataset
    education_terms = df_education_terms_clean["Education-related Key Word"].tolist()
    
    # Separate single words and phrases
    single_words = [term for term in education_terms if len(term.split()) == 1]
    phrases = [term for term in education_terms if len(term.split()) > 1]
    
    # Count single-word matches
    c_tok = Counter(toks)
    single = sum(c_tok.get(w, 0) for w in single_words)
    
    # Count phrase matches
    phrase_count = 0
    for phrase in phrases:
        phrase_count += text_lower.count(phrase)
    
    total = single + phrase_count
    return {
        "n_tokens": n,
        "edu_single_count": single,
        "edu_phrase_count": phrase_count,
        "edu_total": total,
        "edu_per_1k": total / n * 1000.0
    }

# Extract the education-related words from the speeches
res = df_africa["Speech"].apply(count_education_mentions).apply(pd.Series)
cols = ["n_tokens","edu_single_count","edu_phrase_count","edu_total","edu_per_1k"]
df_africa = df_africa.drop(columns=cols, errors="ignore").join(res)

# Look at rows where edu_phrase_count is non-zero
nonzero_phrase = df_africa[df_africa["edu_phrase_count"] > 0]
print(nonzero_phrase[["Country or Area", "n_tokens", "edu_single_count",
                      "edu_phrase_count", "edu_total", "edu_per_1k"]].head())
# Out:
#     Country or Area  n_tokens  edu_single_count  edu_phrase_count  edu_total  \
# 85         Ethiopia    4324.0               7.0               1.0        8.0
# 273         Lesotho    4803.0               7.0               1.0        8.0
# 316      Madagascar    4044.0               9.0               1.0       10.0
# 352          Rwanda    3168.0               4.0               1.0        5.0
# 766    Sierra Leone    6137.0              16.0               1.0       17.0
#
#      edu_per_1k
# 85     1.850139
# 273    1.665626
# 316    2.472799
# 352    1.578283
# 766    2.770083

# %% [markdown]
# ## 4. Data Preparation and Integration
#
# ### 4.1 Filter rows that have expenditure & literacy rates

# %%
# Filter df_africa to only include rows where both Literacy_Rate and Education_Expenditure_GDP_Pct are not NA
df_africa = df_africa[df_africa["Literacy_Rate"].notna() & df_africa["Education_Expenditure_GDP_Pct"].notna()]
df_africa.head(10)
# Out:
#      ISO-alpha3 Code  Session  Year  \
# 426              SOM       27  1972
# 590              SWZ       31  1976
# 683              RWA       33  1978
# 738              BDI       34  1979
# 870              MAR       37  1982
# 969              TUN       39  1984
# 1066             MWI       42  1987
# 1234             MUS       45  1990
# 1237             BDI       45  1990
# 1310             ZWE       47  1992
#
#                                                  Speech Country or Area  \
# 426   mr. president, my foreign secretary had hoped ...         Somalia
# 590   mr. president, i wish to express my sincere co...        Eswatini
# 683   144. the delegation of rwanda wishes to join i...          Rwanda
# 738   a birth in a family is naturally a source of j...         Burundi
# 870   it gives me great pleasure, mr. president, to ...         Morocco
# 969   allow me, sir, to add my congratulations to al...         Tunisia
# 1066  on behalf of the malawi delegation i should li...          Malawi
# 1234  we are delighted that the forty-fifth regular ...       Mauritius
# 1237  i have the honour to convey to the president a...         Burundi
# 1310  i should like, at the outset to congratulate h...        Zimbabwe
#
#      Region Name  Literacy_Rate  Education_Expenditure_GDP_Pct  n_tokens  \
# 426       Africa       5.404650                        1.10284    5674.0
# 590       Africa      55.325039                        3.71435    2370.0
# 683       Africa      38.243431                        2.23247    2105.0
# 738       Africa      22.508551                        2.80336    5462.0
# 870       Africa      30.257799                        6.12268    4754.0
# 969       Africa      48.190701                        5.51745    3170.0
# 1066      Africa      48.536652                        2.42225    2867.0
# 1234      Africa      79.868660                        3.12822    2651.0
# 1237      Africa      37.384720                        3.35933    3964.0
# 1310      Africa      83.512581                       22.32221    3793.0
#
#       edu_single_count  edu_phrase_count  edu_total  edu_per_1k
# 426                3.0               0.0        3.0    0.528728
# 590                4.0               0.0        4.0    1.687764
# 683                4.0               0.0        4.0    1.900238
# 738               18.0               0.0       18.0    3.295496
# 870               12.0               0.0       12.0    2.524190
# 969                2.0               0.0        2.0    0.630915
# 1066               1.0               0.0        1.0    0.348797
# 1234               8.0               0.0        8.0    3.017729
# 1237              11.0               0.0       11.0    2.774975
# 1310              11.0               0.0       11.0    2.900079

# %% [markdown]
# ## 5. Exploratory Data Analysis
#
# ### 5.1 Trends Over Time: Education-related terms frequency  & Literacy Rates

# %%
# Plot trends over time: education-related terms frequency and literacy rates together

# aggregate by year
yearly = (df_africa
          .reset_index()
          .groupby('Year', as_index=False)
          .agg(edu_per_1k=('edu_per_1k','mean'),
               edu_total=('edu_total','mean'),
               literacy_rate=('Literacy_Rate','mean')))

plt.figure()
plt.plot(yearly['Year'], yearly['edu_per_1k'], label='Education terms / 1000 tokens (Africa avg)')
plt.plot(yearly['Year'], yearly['edu_total'], label='Total education terms (Africa avg)')
plt.plot(yearly['Year'], yearly['literacy_rate'], label='Literacy rate (Africa avg)')
plt.xlabel('Year')
plt.legend()
plt.title('Africa-wide averages over time')
plt.show()

# %% [markdown]
# ### 5.2 UN Speech Analysis

# %% [markdown]
# ### 5.3 Expenditure Analysis

# %%
df_africa.head(10)
df_africa["Literacy_Rate"].head(10)
# Out:
# 426      5.404650
# 590     55.325039
# 683     38.243431
# 738     22.508551
# 870     30.257799
# 969     48.190701
# 1066    48.536652
# 1234    79.868660
# 1237    37.384720
# 1310    83.512581
# Name: Literacy_Rate, dtype: float64

# %% [markdown]
# ### 5.3 Literacy Rates Data Overview

# %%
# Analyze literacy rates for African countries using df_africa

# Extract descriptive statistics about the literacy rates in df_africa
print("Literacy Rate Statistics for African Countries (from df_africa):")
print(df_africa['Literacy_Rate'].describe())

# Compute literacy rates over time
literacy_over_time = df_africa.groupby('Year')['Literacy_Rate'].mean().reset_index()

# Adjust the plot size for better readability
plt.figure(figsize=(12, 5))

# Distribution of all literacy rates within African countries
plt.subplot(1, 2, 1)
plt.hist(df_africa['Literacy_Rate'].dropna(), bins=20, color='green', edgecolor='black')
plt.title('Literacy Rate Distribution Within African Countries')
plt.xlabel('Literacy Rate (%)')
plt.ylabel('Count')

# Literacy rates over time within African countries
plt.subplot(1, 2, 2)
plt.plot(literacy_over_time['Year'], literacy_over_time['Literacy_Rate'], marker='o', color='green')
plt.title('Mean Literacy Rate Over Time Within African Countries')
plt.xlabel('Year')
plt.ylabel('Mean Literacy Rate (%)')

# Print the plots
plt.show()
# Out:
# Literacy Rate Statistics for African Countries (from df_africa):
# count    164.000000
# mean      61.956565
# std       22.848328
# min        5.404650
# 25%       41.322783
# 50%       65.016987
# 75%       81.802794
# max       96.199997
# Name: Literacy_Rate, dtype: float64

# %% [markdown]
# ## 6. Research Question Analysis
#
# ### 6.1 Exploratory Question: Correlation Between Education Words and Literacy Rates

# %%
# Correlation analysis between education word frequency and literacy rates

# Calculate mean education word frequency and total education words per country
# Using correct column names: 'edu_per_1k' and 'n_tokens'
edu_stats = df_africa.groupby('Country or Area').agg({
    'edu_per_1k': 'mean',
    'n_tokens': 'mean',
    'edu_total': 'mean',
    'Literacy_Rate': 'mean',  # Also get mean literacy rate per country
    'Education_Expenditure_GDP_Pct': 'mean'  # And mean expenditure
}).reset_index()

print(f"Countries with education and literacy data: {len(edu_stats)}")
print("\nCountries included in analysis:")
print(edu_stats['Country or Area'].tolist())

# Statistical analysis: Education word frequency per 1k tokens vs Literacy Rate
print("\n=== CORRELATION ANALYSIS ===")

# Pearson correlation for education frequency
corr_freq, p_freq = stats.pearsonr(edu_stats['edu_per_1k'], edu_stats['Literacy_Rate'])
print(f"Pearson correlation (edu words per 1k tokens vs literacy): {corr_freq:.3f} (p={p_freq:.3g})")

# Spearman correlation (rank-based, more robust to outliers)
corr_freq_spear, p_freq_spear = stats.spearmanr(edu_stats['edu_per_1k'], edu_stats['Literacy_Rate'])
print(f"Spearman correlation (edu words per 1k tokens vs literacy): {corr_freq_spear:.3f} (p={p_freq_spear:.3g})")

# Pearson correlation for total education words
corr_total, p_total = stats.pearsonr(edu_stats['edu_total'], edu_stats['Literacy_Rate'])
print(f"Pearson correlation (total edu words vs literacy): {corr_total:.3f} (p={p_total:.3g})")

# Spearman correlation for total education words
corr_total_spear, p_total_spear = stats.spearmanr(edu_stats['edu_total'], edu_stats['Literacy_Rate'])
print(f"Spearman correlation (total edu words vs literacy): {corr_total_spear:.3f} (p={p_total_spear:.3g})")
# Out:
# Countries with education and literacy data: 43
#
# Countries included in analysis:
# ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'Sudan', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe']
#
# === CORRELATION ANALYSIS ===
# Pearson correlation (edu words per 1k tokens vs literacy): -0.134 (p=0.392)
# Spearman correlation (edu words per 1k tokens vs literacy): -0.169 (p=0.278)
# Pearson correlation (total edu words vs literacy): -0.181 (p=0.247)
# Spearman correlation (total edu words vs literacy): -0.221 (p=0.155)

# %%
# Create figure with subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Scatter plot: Education word frequency per 1k vs Literacy Rate
axes[0,0].scatter(edu_stats['edu_per_1k'], edu_stats['Literacy_Rate'], alpha=0.7)
if len(edu_stats) > 1:
    z_freq = np.polyfit(edu_stats['edu_per_1k'], edu_stats['Literacy_Rate'], 1)
    axes[0,0].plot(edu_stats['edu_per_1k'], np.polyval(z_freq, edu_stats['edu_per_1k']), "r--")
axes[0,0].set_xlabel('Education Words per 1k Tokens')
axes[0,0].set_ylabel('Literacy Rate (%)')
axes[0,0].set_title(f'Education Frequency vs Literacy Rate\n(r = {corr_freq:.3f})')

# Scatter plot: Total education words vs Literacy Rate
axes[0,1].scatter(edu_stats['edu_total'], edu_stats['Literacy_Rate'], alpha=0.7)
if len(edu_stats) > 1 and edu_stats['edu_total'].nunique() > 1:
    z_total = np.polyfit(edu_stats['edu_total'], edu_stats['Literacy_Rate'], 1)
    axes[0,1].plot(edu_stats['edu_total'], np.polyval(z_total, edu_stats['edu_total']), "r--")
axes[0,1].set_xlabel('Total Education Words (mean per country)')
axes[0,1].set_ylabel('Literacy Rate (%)')
axes[0,1].set_title(f'Total Education Words vs Literacy Rate\n(r = {corr_total:.3f})')

# Histogram of education frequency
axes[1,0].hist(edu_stats['edu_per_1k'], bins=10, alpha=0.7, edgecolor='black')
axes[1,0].set_xlabel('Education Words per 1k Tokens')
axes[1,0].set_ylabel('Frequency')
axes[1,0].set_title('Distribution of Education Word Frequency')

# Histogram of literacy rates
axes[1,1].hist(edu_stats['Literacy_Rate'], bins=10, alpha=0.7, edgecolor='black')
axes[1,1].set_xlabel('Literacy Rate (%)')
axes[1,1].set_ylabel('Frequency')
axes[1,1].set_title('Distribution of Literacy Rates')

plt.tight_layout()
plt.show()

# --- Summary statistics ---
print("\n=== SUMMARY STATISTICS ===")
print("Education word frequency per 1k tokens and literacy rate:")
print(edu_stats[['edu_per_1k', 'Literacy_Rate']].describe())
print("\nTotal education words and literacy rate:")
print(edu_stats[['edu_total', 'Literacy_Rate']].describe())

# --- Outlier Analysis ---
print("\n=== OUTLIER ANALYSIS ===")

# Identify outliers using IQR method
def identify_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers, lower_bound, upper_bound

# Check for outliers in education frequency
edu_outliers, edu_lower, edu_upper = identify_outliers(edu_stats, 'edu_per_1k')
print(f"Education frequency outliers (outside {edu_lower:.2f} - {edu_upper:.2f}):")
if len(edu_outliers) > 0:
    print(edu_outliers[['Country or Area', 'edu_per_1k', 'Literacy_Rate']])
else:
    print("No outliers found")

# Check for outliers in literacy rate
lit_outliers, lit_lower, lit_upper = identify_outliers(edu_stats, 'Literacy_Rate')
print(f"\nLiteracy rate outliers (outside {lit_lower:.2f} - {lit_upper:.2f}):")
if len(lit_outliers) > 0:
    print(lit_outliers[['Country or Area', 'edu_per_1k', 'Literacy_Rate']])
else:
    print("No outliers found")

# Show countries with highest and lowest education word usage
print(f"\n=== TOP AND BOTTOM PERFORMERS ===")
print("Countries with highest education word frequency:")
print(edu_stats.nlargest(3, 'edu_per_1k')[['Country or Area', 'edu_per_1k', 'Literacy_Rate']])
print("\nCountries with lowest education word frequency:")
print(edu_stats.nsmallest(3, 'edu_per_1k')[['Country or Area', 'edu_per_1k', 'Literacy_Rate']])
# Out:
# === SUMMARY STATISTICS ===
# Education word frequency per 1k tokens and literacy rate:
#        edu_per_1k  Literacy_Rate
# count   43.000000      43.000000
# mean     2.891579      62.171781
# std      1.620527      21.492290
# min      0.528728       5.404650
# 25%      1.673745      48.016584
# 50%      2.540872      64.514374
# 75%      3.576598      79.055843
# max      8.315385      92.005573
#
# Total education words and literacy rate:
#        edu_total  Literacy_Rate
# count  43.000000      43.000000
# mean    5.619462      62.171781
# std     3.108482      21.492290
# min     1.000000       5.404650
# 25%     3.000000      48.016584
# 50%     5.428571      64.514374
# 75%     7.333333      79.055843
# max    13.500000      92.005573
#
# === OUTLIER ANALYSIS ===
# Education frequency outliers (outside -1.18 - 6.43):
#    Country or Area  edu_per_1k  Literacy_Rate
# 11         Eritrea    6.586169      52.513950
# 13        Ethiopia    8.315385      45.383579
#
# Literacy rate outliers (outside 1.46 - 125.61):
# No outliers found
#
# === TOP AND BOTTOM PERFORMERS ===
# Countries with highest education word frequency:
#    Country or Area  edu_per_1k  Literacy_Rate
# 13        Ethiopia    8.315385      45.383579
# 11         Eritrea    6.586169      52.513950
# 23      Mauritania    5.682873      64.514374
#
# Countries with lowest education word frequency:
#    Country or Area  edu_per_1k  Literacy_Rate
# 35         Somalia    0.528728       5.404650
# 33      Seychelles    0.651466      92.005573
# 0          Algeria    0.967025      78.271942

# %% [markdown]
# ### 6.2 Predictive Question: <>
